# %%
import openai
import pandas as pd
from googleapiclient import discovery
import json
from googleapiclient.errors import HttpError
import time
import numpy as np
import os
import glob
import re

# %%
# Sampling 1000 observations
# text = pd.read_fwf(
#     '../data/raw/tweeteval_test_text.txt', 
#     header=None,
#     names=['text']
#     )
# labels = pd.read_fwf(
#     '../data/raw/tweeteval_test_labels.txt', 
#     header=None,
#     names=['label']
#     )
# test_df = text.join(labels)

# test_df = test_df.reset_index().rename(
#     columns={'index': 'id'})
# test_df.to_csv(
#     '../data/raw/tweeteval_test.txt',
#     index=False
#     )
# test_df = pd.read_csv(
#     '../data/raw/tweeteval_test.txt'
# )
# test_df.sample(1000, random_state=3).to_csv(
#     '../data/interim/sampled_tweeteval_test.txt',
#     index=False
# )

# %%
test_df_sampled = pd.read_csv(
    '../data/interim/sampled_tweeteval_test.txt'
)

# %%
with open('../api_key.txt', 'r') as file:
    PERSPECTIVE_API_KEY = file.read().rstrip()

# %%
with open('../gpt_key.txt', 'r') as file:
    openai.api_key = file.read().rstrip()

# %%
client = discovery.build(
  "commentanalyzer",
  "v1alpha1",
  developerKey=PERSPECTIVE_API_KEY,
  discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  static_discovery=False,
)

# %%
def score_row_perspective(row, score_type_list, add_delay=True, overwrite=False):
    path = f"../data/perspective_api/perspective_{row['id']}.json"
    file_exists = os.path.exists(path)
    if (overwrite) or (not file_exists): 
        if add_delay:
            time.sleep(1)
        try:
            score_type_attribute = {value: {} for value in score_type_list}
            analyze_request = {
                'comment': { 'text': row['text'] },
                'requestedAttributes': score_type_attribute
            }
            response = client.comments().analyze(body=analyze_request).execute()
        except HttpError as err:
            if err.resp.status == 429:
                print('Quota limit exceeded')
                time.sleep(10)
                response = client.comments().analyze(body=analyze_request).execute()
            elif err.resp.status == 400:
                print(err)
                print(f"Language not found error for sentence: {row['text']}, id:{row['id']}")
                response = {"attributeScores": {}, "error": str(err)}
            else:
                print(err.resp.status)
                print(f"Error in id {row['id']}")
                raise
        with open(path, 'w') as f:
            json.dump(response, f)
    else:
        print(f"Skipping because id {row['id']} already exists")
    return

# %%
def parse_boolean_text(t):
    # NOTE: We assume here that we get an answer from a well behaved set
    # We signify another response (should be rare) with -1,
    # and inspect these by hand
    t = t.lower().split(' ')
    for val in ['true', 'false', 'yes', 'no', 'true.', 'false.', 'yes.', 'no.']:
        if val in t:
            return int(val == 'true') or int(val == 'yes')

    # Special case: sometimes GPT3 returns a negation.
    # I.e. "This phrase is not toxic" -> false
    # this might be a bit of a hacky fix...
    if 'not' in t:
        return 0
    return -1

def score_row_gpt3(
    row, shot_num='few', 
    add_delay=True, temperature = 0.3,
    overwrite=False
    ):
    path = f"../data/openai_api/gpt3_{row['id']}.json"
    file_exists = os.path.exists(path)
    if (overwrite) or (not file_exists): 
        if shot_num == 'one':
            prompt = f"""Determine if the given phrase is toxic:
                    Men are superior to women in every way. => True
                    {row['text']} =>"""
        elif shot_num == 'few':
            prompt = f"""Determine if the given phrase is toxic:
                    Men are superior to women in every way. => True
                    Grilling with the neighbors is my favorite. => False
                    {row['text']} =>"""
        
        if add_delay:
            time.sleep(1)
        try:
            response = openai.Completion.create(
                    engine="text-davinci-001",
                    prompt=prompt,
                    temperature=temperature,
                )
        except:
            time.sleep(10)
            response = openai.Completion.create(
                    engine="text-davinci-001",
                    prompt=prompt,
                    temperature=temperature,
                )
        with open(path, 'w') as f:
            json.dump(response, f)
    else:
        print(f"Skipping because id {row['id']} already exists")

# %%
score_type_map_toxicity = {
    "toxicity_score": "TOXICITY",
}
score_col_names = list(score_type_map_toxicity.keys()) #list(score_type_map_full.keys())
score_type_list = list(score_type_map_toxicity.values()) #list(score_type_map_full.values())

# %%
test_df_sampled.apply(
    lambda row: score_row_gpt3(
        row=row),
    axis=1
)
# Out:
# Skipping because id 1165 already exists
# Skipping because id 437 already exists
# Skipping because id 2671 already exists
# Skipping because id 1027 already exists
# Skipping because id 164 already exists
# Skipping because id 1212 already exists
# Skipping because id 1200 already exists
# Skipping because id 1942 already exists
# Skipping because id 1380 already exists
# Skipping because id 2937 already exists
# Skipping because id 1845 already exists
# Skipping because id 266 already exists
# Skipping because id 1102 already exists
# Skipping because id 1237 already exists
# Skipping because id 1457 already exists
# Skipping because id 57 already exists
# Skipping because id 2035 already exists
# Skipping because id 2454 already exists
# Skipping because id 2002 already exists
# Skipping because id 21 already exists
# Skipping because id 2342 already exists
# Skipping because id 1052 already exists
# Skipping because id 1113 already exists
# Skipping because id 1807 already exists
# Skipping because id 2557 already exists
# Skipping because id 1545 already exists
# Skipping because id 2840 already exists
# Skipping because id 1035 already exists
# Skipping because id 2193 already exists
# Skipping because id 1784 already exists
# Skipping because id 443 already exists
# Skipping because id 1283 already exists
# Skipping because id 781 already exists
# Skipping because id 1516 already exists
# Skipping because id 697 already exists
# Skipping because id 551 already exists
# Skipping because id 1120 already exists
# Skipping because id 2967 already exists
# Skipping because id 30 already exists
# Skipping because id 346 already exists
# Skipping because id 2040 already exists
# Skipping because id 1675 already exists
# Skipping because id 2296 already exists
# Skipping because id 2725 already exists
# Skipping because id 2228 already exists
# Skipping because id 392 already exists
# Skipping because id 1774 already exists
# Skipping because id 2635 already exists
# Skipping because id 540 already exists
# Skipping because id 1634 already exists
# Skipping because id 1512 already exists
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Length: 1000, dtype: object

# %%
test_df_sampled.apply(
    lambda row: score_row_perspective(
        row=row,
        score_type_list=score_type_list
        ),
    axis=1
)
# Out:
# Skipping because id 1165 already exists
# Skipping because id 437 already exists
# Skipping because id 2671 already exists
# Skipping because id 1027 already exists
# Skipping because id 164 already exists
# Skipping because id 1212 already exists
# Skipping because id 1200 already exists
# Skipping because id 1942 already exists
# Skipping because id 1380 already exists
# Skipping because id 2937 already exists
# Skipping because id 1845 already exists
# Skipping because id 266 already exists
# Skipping because id 1102 already exists
# Skipping because id 1237 already exists
# Skipping because id 1457 already exists
# Skipping because id 57 already exists
# Skipping because id 2035 already exists
# Skipping because id 2454 already exists
# Skipping because id 2002 already exists
# Skipping because id 21 already exists
# Skipping because id 2342 already exists
# Skipping because id 1052 already exists
# Skipping because id 1113 already exists
# Skipping because id 1807 already exists
# Skipping because id 2557 already exists
# Skipping because id 1545 already exists
# Skipping because id 2840 already exists
# Skipping because id 1035 already exists
# Skipping because id 2193 already exists
# Skipping because id 1784 already exists
# Skipping because id 443 already exists
# Skipping because id 1283 already exists
# Skipping because id 781 already exists
# Skipping because id 1516 already exists
# Skipping because id 697 already exists
# Skipping because id 551 already exists
# Skipping because id 1120 already exists
# Skipping because id 2967 already exists
# Skipping because id 30 already exists
# Skipping because id 346 already exists
# Skipping because id 2040 already exists
# Skipping because id 1675 already exists
# Skipping because id 2296 already exists
# Skipping because id 2725 already exists
# Skipping because id 2228 already exists
# Skipping because id 392 already exists
# Skipping because id 1774 already exists
# Skipping because id 2635 already exists
# Skipping because id 540 already exists
# Skipping because id 1634 already exists
# Skipping because id 1512 already exists
# Skipping because id 1204 already exists
# Skipping because id 1040 already exists
# Skipping because id 175 already exists
# Skipping because id 630 already exists
# Skipping because id 602 already exists
# Skipping because id 2429 already exists
# Skipping because id 2927 already exists
# Skipping because id 1105 already exists
# Skipping because id 2945 already exists
# Skipping because id 2379 already exists
# Skipping because id 558 already exists
# Skipping because id 332 already exists
# Skipping because id 1799 already exists
# Skipping because id 2175 already exists
# Skipping because id 2562 already exists
# Skipping because id 2009 already exists
# Skipping because id 459 already exists
# Skipping because id 1986 already exists
# Skipping because id 1844 already exists
# Skipping because id 853 already exists
# Skipping because id 2578 already exists
# Skipping because id 226 already exists
# Skipping because id 1622 already exists
# Skipping because id 2131 already exists
# Skipping because id 966 already exists
# Skipping because id 597 already exists
# Skipping because id 87 already exists
# Skipping because id 2443 already exists
# Skipping because id 377 already exists
# Skipping because id 1014 already exists
# Skipping because id 899 already exists
# Skipping because id 1439 already exists
# Skipping because id 654 already exists
# Skipping because id 2156 already exists
# Skipping because id 202 already exists
# Skipping because id 838 already exists
# Skipping because id 693 already exists
# Skipping because id 1352 already exists
# Skipping because id 908 already exists
# Skipping because id 2715 already exists
# Skipping because id 2569 already exists
# Skipping because id 454 already exists
# Skipping because id 1522 already exists
# Skipping because id 389 already exists
# Skipping because id 890 already exists
# Skipping because id 236 already exists
# Skipping because id 2239 already exists
# Skipping because id 940 already exists
# Skipping because id 549 already exists
# Skipping because id 2966 already exists
# Skipping because id 1510 already exists
# Skipping because id 414 already exists
# Skipping because id 2519 already exists
# Skipping because id 209 already exists
# Skipping because id 1924 already exists
# Skipping because id 1055 already exists
# Skipping because id 1755 already exists
# Skipping because id 2247 already exists
# Skipping because id 1008 already exists
# Skipping because id 2067 already exists
# Skipping because id 724 already exists
# Skipping because id 718 already exists
# Skipping because id 1223 already exists
# Skipping because id 2337 already exists
# Skipping because id 1491 already exists
# Skipping because id 2087 already exists
# Skipping because id 481 already exists
# Skipping because id 1783 already exists
# Skipping because id 1125 already exists
# Skipping because id 2843 already exists
# Skipping because id 822 already exists
# Skipping because id 1020 already exists
# Skipping because id 932 already exists
# Skipping because id 1604 already exists
# Skipping because id 1971 already exists
# Skipping because id 1747 already exists
# Skipping because id 1233 already exists
# Skipping because id 1584 already exists
# Skipping because id 445 already exists
# Skipping because id 942 already exists
# Skipping because id 1839 already exists
# Skipping because id 768 already exists
# Skipping because id 1437 already exists
# Skipping because id 2518 already exists
# Skipping because id 2509 already exists
# Skipping because id 160 already exists
# Skipping because id 1648 already exists
# Skipping because id 2673 already exists
# Skipping because id 246 already exists
# Skipping because id 3 already exists
# Skipping because id 1892 already exists
# Skipping because id 2243 already exists
# Skipping because id 2829 already exists
# Skipping because id 250 already exists
# Skipping because id 1358 already exists
# Skipping because id 2692 already exists
# Skipping because id 2144 already exists
# Skipping because id 2052 already exists
# Skipping because id 1693 already exists
# Skipping because id 2115 already exists
# Skipping because id 1852 already exists
# Skipping because id 25 already exists
# Skipping because id 2275 already exists
# Skipping because id 1515 already exists
# Skipping because id 2902 already exists
# Skipping because id 617 already exists
# Skipping because id 1099 already exists
# Skipping because id 1344 already exists
# Skipping because id 269 already exists
# Skipping because id 403 already exists
# Skipping because id 2290 already exists
# Skipping because id 1623 already exists
# Skipping because id 1374 already exists
# Skipping because id 2374 already exists
# Skipping because id 1978 already exists
# Skipping because id 273 already exists
# Skipping because id 584 already exists
# Skipping because id 1051 already exists
# Skipping because id 1919 already exists
# Skipping because id 2486 already exists
# Skipping because id 22 already exists
# Skipping because id 532 already exists
# Skipping because id 1879 already exists
# Skipping because id 1441 already exists
# Skipping because id 2302 already exists
# Skipping because id 1972 already exists
# Skipping because id 2369 already exists
# Skipping because id 2241 already exists
# Skipping because id 1531 already exists
# Skipping because id 669 already exists
# Skipping because id 615 already exists
# Skipping because id 2186 already exists
# Skipping because id 72 already exists
# Skipping because id 469 already exists
# Skipping because id 792 already exists
# Skipping because id 1007 already exists
# Skipping because id 1647 already exists
# Skipping because id 912 already exists
# Skipping because id 1123 already exists
# Skipping because id 1400 already exists
# Skipping because id 636 already exists
# Skipping because id 6 already exists
# Skipping because id 2574 already exists
# Skipping because id 892 already exists
# Skipping because id 1198 already exists
# Skipping because id 1132 already exists
# Skipping because id 2763 already exists
# Skipping because id 0 already exists
# Skipping because id 837 already exists
# Skipping because id 2530 already exists
# Skipping because id 1296 already exists
# Skipping because id 2259 already exists
# Skipping because id 922 already exists
# Skipping because id 1609 already exists
# Skipping because id 1508 already exists
# Skipping because id 2643 already exists
# Skipping because id 2777 already exists
# Skipping because id 2054 already exists
# Skipping because id 1754 already exists
# Skipping because id 2507 already exists
# Skipping because id 1326 already exists
# Skipping because id 915 already exists
# Skipping because id 2723 already exists
# Skipping because id 2153 already exists
# Skipping because id 898 already exists
# Skipping because id 334 already exists
# Skipping because id 961 already exists
# Skipping because id 1107 already exists
# Skipping because id 2750 already exists
# Skipping because id 933 already exists
# Skipping because id 1672 already exists
# Skipping because id 1440 already exists
# Skipping because id 1199 already exists
# Skipping because id 2287 already exists
# Skipping because id 1639 already exists
# Skipping because id 1477 already exists
# Skipping because id 1821 already exists
# Skipping because id 850 already exists
# Skipping because id 2345 already exists
# Skipping because id 1872 already exists
# Skipping because id 544 already exists
# Skipping because id 1348 already exists
# Skipping because id 2891 already exists
# Skipping because id 901 already exists
# Skipping because id 719 already exists
# Skipping because id 120 already exists
# Skipping because id 439 already exists
# Skipping because id 2604 already exists
# Skipping because id 1349 already exists
# Skipping because id 557 already exists
# Skipping because id 2732 already exists
# Skipping because id 1197 already exists
# Skipping because id 208 already exists
# Skipping because id 2254 already exists
# Skipping because id 805 already exists
# Skipping because id 1273 already exists
# Skipping because id 2251 already exists
# Skipping because id 126 already exists
# Skipping because id 69 already exists
# Skipping because id 1011 already exists
# Skipping because id 692 already exists
# Skipping because id 1122 already exists
# Skipping because id 2230 already exists
# Skipping because id 2234 already exists
# Skipping because id 404 already exists
# Skipping because id 586 already exists
# Skipping because id 1726 already exists
# Skipping because id 1038 already exists
# Skipping because id 1730 already exists
# Skipping because id 1969 already exists
# Skipping because id 2490 already exists
# Skipping because id 1402 already exists
# Skipping because id 388 already exists
# Skipping because id 124 already exists
# Skipping because id 216 already exists
# Skipping because id 1336 already exists
# Skipping because id 166 already exists
# Skipping because id 2809 already exists
# Skipping because id 228 already exists
# Skipping because id 317 already exists
# Skipping because id 2775 already exists
# Skipping because id 1208 already exists
# Skipping because id 2805 already exists
# Skipping because id 312 already exists
# Skipping because id 1365 already exists
# Skipping because id 2011 already exists
# Skipping because id 350 already exists
# Skipping because id 328 already exists
# Skipping because id 934 already exists
# Skipping because id 1277 already exists
# Skipping because id 800 already exists
# Skipping because id 86 already exists
# Skipping because id 2542 already exists
# Skipping because id 1797 already exists
# Skipping because id 1507 already exists
# Skipping because id 828 already exists
# Skipping because id 2758 already exists
# Skipping because id 1542 already exists
# Skipping because id 472 already exists
# Skipping because id 1927 already exists
# Skipping because id 1462 already exists
# Skipping because id 2421 already exists
# Skipping because id 1549 already exists
# Skipping because id 1989 already exists
# Skipping because id 123 already exists
# Skipping because id 1535 already exists
# Skipping because id 604 already exists
# Skipping because id 1605 already exists
# Skipping because id 318 already exists
# Skipping because id 1444 already exists
# Skipping because id 1567 already exists
# Skipping because id 2879 already exists
# Skipping because id 2310 already exists
# Skipping because id 876 already exists
# Skipping because id 1487 already exists
# Skipping because id 1088 already exists
# Skipping because id 2192 already exists
# Skipping because id 2888 already exists
# Skipping because id 1163 already exists
# Skipping because id 536 already exists
# Skipping because id 2163 already exists
# Skipping because id 2327 already exists
# Skipping because id 2298 already exists
# Skipping because id 2854 already exists
# Skipping because id 1685 already exists
# Skipping because id 2691 already exists
# Skipping because id 1729 already exists
# Skipping because id 1806 already exists
# Skipping because id 347 already exists
# Skipping because id 2135 already exists
# Skipping because id 1499 already exists
# Skipping because id 914 already exists
# Skipping because id 1496 already exists
# Skipping because id 65 already exists
# Skipping because id 1156 already exists
# Skipping because id 2644 already exists
# Skipping because id 852 already exists
# Skipping because id 2751 already exists
# Skipping because id 2527 already exists
# Skipping because id 5 already exists
# Skipping because id 1455 already exists
# Skipping because id 2633 already exists
# Skipping because id 2173 already exists
# Skipping because id 111 already exists
# Skipping because id 2864 already exists
# Skipping because id 1500 already exists
# Skipping because id 1863 already exists
# Skipping because id 2079 already exists
# Skipping because id 499 already exists
# Skipping because id 41 already exists
# Skipping because id 2893 already exists
# Skipping because id 1586 already exists
# Skipping because id 301 already exists
# Skipping because id 1785 already exists
# Skipping because id 370 already exists
# Skipping because id 841 already exists
# Skipping because id 1673 already exists
# Skipping because id 1360 already exists
# Skipping because id 2194 already exists
# Skipping because id 1948 already exists
# Skipping because id 211 already exists
# Skipping because id 1559 already exists
# Skipping because id 157 already exists
# Skipping because id 156 already exists
# Skipping because id 2718 already exists
# Skipping because id 2295 already exists
# Skipping because id 1897 already exists
# Skipping because id 2575 already exists
# Skipping because id 2641 already exists
# Skipping because id 103 already exists
# Skipping because id 1370 already exists
# Skipping because id 1956 already exists
# Skipping because id 240 already exists
# Skipping because id 371 already exists
# Skipping because id 1830 already exists
# Skipping because id 856 already exists
# Skipping because id 140 already exists
# Skipping because id 2757 already exists
# Skipping because id 1602 already exists
# Skipping because id 2934 already exists
# Skipping because id 1424 already exists
# Skipping because id 562 already exists
# Skipping because id 1244 already exists
# Skipping because id 2558 already exists
# Skipping because id 1660 already exists
# Skipping because id 1943 already exists
# Skipping because id 1386 already exists
# Skipping because id 2216 already exists
# Skipping because id 2531 already exists
# Skipping because id 339 already exists
# Skipping because id 2468 already exists
# Skipping because id 1488 already exists
# Skipping because id 1831 already exists
# Skipping because id 194 already exists
# Skipping because id 2044 already exists
# Skipping because id 1547 already exists
# Skipping because id 2176 already exists
# Skipping because id 1210 already exists
# Skipping because id 2613 already exists
# Skipping because id 1361 already exists
# Skipping because id 398 already exists
# Skipping because id 1791 already exists
# Skipping because id 2364 already exists
# Skipping because id 1119 already exists
# Skipping because id 1026 already exists
# Skipping because id 34 already exists
# Skipping because id 410 already exists
# Skipping because id 1501 already exists
# Skipping because id 270 already exists
# Skipping because id 2299 already exists
# Skipping because id 422 already exists
# Skipping because id 1636 already exists
# Skipping because id 192 already exists
# Skipping because id 1109 already exists
# Skipping because id 2405 already exists
# Skipping because id 1563 already exists
# Skipping because id 2423 already exists
# Skipping because id 330 already exists
# Skipping because id 1260 already exists
# Skipping because id 2475 already exists
# Skipping because id 2832 already exists
# Skipping because id 1843 already exists
# Skipping because id 877 already exists
# Skipping because id 1201 already exists
# Skipping because id 325 already exists
# Skipping because id 2614 already exists
# Skipping because id 916 already exists
# Skipping because id 2483 already exists
# Skipping because id 2117 already exists
# Skipping because id 1568 already exists
# Skipping because id 1947 already exists
# Skipping because id 131 already exists
# Skipping because id 1322 already exists
# Skipping because id 2546 already exists
# Skipping because id 1087 already exists
# Skipping because id 1460 already exists
# Skipping because id 2335 already exists
# Skipping because id 2317 already exists
# Skipping because id 2116 already exists
# Skipping because id 2409 already exists
# Skipping because id 59 already exists
# Skipping because id 362 already exists
# Skipping because id 2627 already exists
# Skipping because id 2098 already exists
# Skipping because id 2311 already exists
# Skipping because id 1835 already exists
# Skipping because id 1065 already exists
# Skipping because id 1802 already exists
# Skipping because id 2008 already exists
# Skipping because id 2406 already exists
# Skipping because id 1769 already exists
# Skipping because id 2147 already exists
# Skipping because id 1701 already exists
# Skipping because id 183 already exists
# Skipping because id 1037 already exists
# Skipping because id 293 already exists
# Skipping because id 2482 already exists
# Skipping because id 1061 already exists
# Skipping because id 2416 already exists
# Skipping because id 2659 already exists
# Skipping because id 814 already exists
# Skipping because id 2577 already exists
# Skipping because id 2114 already exists
# Skipping because id 2564 already exists
# Skipping because id 471 already exists
# Skipping because id 2788 already exists
# Skipping because id 303 already exists
# Skipping because id 2191 already exists
# Skipping because id 2474 already exists
# Skipping because id 603 already exists
# Skipping because id 2826 already exists
# Skipping because id 2020 already exists
# Skipping because id 1859 already exists
# Skipping because id 391 already exists
# Skipping because id 1264 already exists
# Skipping because id 2953 already exists
# Skipping because id 1914 already exists
# Skipping because id 38 already exists
# Skipping because id 2433 already exists
# Skipping because id 361 already exists
# Skipping because id 356 already exists
# Skipping because id 91 already exists
# Skipping because id 1092 already exists
# Skipping because id 2597 already exists
# Skipping because id 1764 already exists
# Skipping because id 73 already exists
# Skipping because id 229 already exists
# Skipping because id 2813 already exists
# Skipping because id 1259 already exists
# Skipping because id 458 already exists
# Skipping because id 1847 already exists
# Skipping because id 741 already exists
# Skipping because id 1414 already exists
# Skipping because id 82 already exists
# Skipping because id 2648 already exists
# Skipping because id 1991 already exists
# Skipping because id 1800 already exists
# Skipping because id 272 already exists
# Skipping because id 2157 already exists
# Skipping because id 1817 already exists
# Skipping because id 1041 already exists
# Skipping because id 1992 already exists
# Skipping because id 823 already exists
# Skipping because id 1538 already exists
# Skipping because id 2624 already exists
# Skipping because id 2030 already exists
# Skipping because id 2583 already exists
# Skipping because id 2300 already exists
# Skipping because id 2343 already exists
# Skipping because id 802 already exists
# Skipping because id 1070 already exists
# Skipping because id 1115 already exists
# Skipping because id 446 already exists
# Skipping because id 888 already exists
# Skipping because id 891 already exists
# Skipping because id 626 already exists
# Skipping because id 1503 already exists
# Skipping because id 1745 already exists
# Skipping because id 2816 already exists
# Skipping because id 1224 already exists
# Skipping because id 1711 already exists
# Skipping because id 2462 already exists
# Skipping because id 2055 already exists
# Skipping because id 2719 already exists
# Skipping because id 1231 already exists
# Skipping because id 1713 already exists
# Skipping because id 2956 already exists
# Skipping because id 911 already exists
# Skipping because id 1853 already exists
# Skipping because id 2793 already exists
# Skipping because id 894 already exists
# Skipping because id 448 already exists
# Skipping because id 212 already exists
# Skipping because id 765 already exists
# Skipping because id 2932 already exists
# Skipping because id 1169 already exists
# Skipping because id 563 already exists
# Skipping because id 1543 already exists
# Skipping because id 1691 already exists
# Skipping because id 729 already exists
# Skipping because id 2697 already exists
# Skipping because id 2408 already exists
# Skipping because id 1117 already exists
# Skipping because id 632 already exists
# Skipping because id 1952 already exists
# Skipping because id 440 already exists
# Skipping because id 592 already exists
# Skipping because id 2683 already exists
# Skipping because id 730 already exists
# Skipping because id 1809 already exists
# Skipping because id 2605 already exists
# Skipping because id 407 already exists
# Skipping because id 1671 already exists
# Skipping because id 1222 already exists
# Skipping because id 2571 already exists
# Skipping because id 1059 already exists
# Skipping because id 2222 already exists
# Skipping because id 2921 already exists
# Skipping because id 285 already exists
# Skipping because id 2791 already exists
# Skipping because id 1495 already exists
# Skipping because id 1337 already exists
# Skipping because id 2880 already exists
# Skipping because id 2107 already exists
# Skipping because id 1028 already exists
# Skipping because id 1141 already exists
# Skipping because id 1182 already exists
# Skipping because id 2702 already exists
# Skipping because id 349 already exists
# Skipping because id 2658 already exists
# Skipping because id 880 already exists
# Skipping because id 695 already exists
# Skipping because id 1686 already exists
# Skipping because id 1574 already exists
# Skipping because id 2803 already exists
# Skipping because id 2634 already exists
# Skipping because id 1548 already exists
# Skipping because id 1756 already exists
# Skipping because id 1966 already exists
# Skipping because id 1638 already exists
# Skipping because id 628 already exists
# Skipping because id 2400 already exists
# Skipping because id 980 already exists
# Skipping because id 2544 already exists
# Skipping because id 319 already exists
# Skipping because id 515 already exists
# Skipping because id 1757 already exists
# Skipping because id 510 already exists
# Skipping because id 2270 already exists
# Skipping because id 2455 already exists
# Skipping because id 958 already exists
# Skipping because id 2088 already exists
# Skipping because id 2094 already exists
# Skipping because id 1170 already exists
# Skipping because id 1654 already exists
# Skipping because id 1659 already exists
# Skipping because id 1736 already exists
# Skipping because id 355 already exists
# Skipping because id 1207 already exists
# Skipping because id 50 already exists
# Skipping because id 2744 already exists
# Skipping because id 2778 already exists
# Skipping because id 62 already exists
# Skipping because id 652 already exists
# Skipping because id 902 already exists
# Skipping because id 1404 already exists
# Skipping because id 967 already exists
# Skipping because id 2885 already exists
# Skipping because id 2198 already exists
# Skipping because id 1928 already exists
# Skipping because id 1136 already exists
# Skipping because id 412 already exists
# Skipping because id 2876 already exists
# Skipping because id 1606 already exists
# Skipping because id 2399 already exists
# Skipping because id 2458 already exists
# Skipping because id 1069 already exists
# Skipping because id 590 already exists
# Skipping because id 2625 already exists
# Skipping because id 83 already exists
# Skipping because id 2622 already exists
# Skipping because id 973 already exists
# Skipping because id 1368 already exists
# Skipping because id 1824 already exists
# Skipping because id 1328 already exists
# Skipping because id 1552 already exists
# Skipping because id 400 already exists
# Skipping because id 1183 already exists
# Skipping because id 2221 already exists
# Skipping because id 613 already exists
# Skipping because id 2223 already exists
# Skipping because id 1213 already exists
# Skipping because id 2032 already exists
# Skipping because id 1194 already exists
# Skipping because id 2016 already exists
# Skipping because id 245 already exists
# Skipping because id 222 already exists
# <HttpError 400 when requesting https://commentanalyzer.googleapis.com/v1alpha1/comments:analyze?key=AIzaSyBm45uDASdOtyMPIDdIS3jdHNWN81-TzKw&alt=json returned "Attribute TOXICITY does not support request languages: mg". Details: "[{'@type': 'type.googleapis.com/google.commentanalyzer.v1alpha1.Error', 'errorType': 'LANGUAGE_NOT_SUPPORTED_BY_ATTRIBUTE', 'languageNotSupportedByAttributeError': {'detectedLanguages': ['mg'], 'attribute': 'TOXICITY'}}]">
# Language not found error for sentence: @user @user 1) #EndHealthcareCartel, 2) #EndDACA, 3) Abolish #IranDeal, 4) #EndNAFTA, 5) #BuildTheWall, 6) #FairTax, 7) #DrainTheSwamp, 8) #FairTrade, 9) #BanIslam, 10) #LockHerUp, 11) #EndSanctuaryCities, & 12) #EndCorporateWelfare. #USA, id:232
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 995    None
# 996    None
# 997    None
# 998    None
# 999    None
# Length: 1000, dtype: object

# %% [markdown]
# # Join in one dataset

# %%
file_paths_gpt3 = glob.glob('../data/openai_api/*')
file_paths_perspective = glob.glob('../data/perspective_api/*')

# %%
def read_json(file_path):
    with open(file_path) as f:
        data = json.load(f)
    return data

# %%
def read_and_parse_gpt3(file_path):
    id = re.findall(r'\d+',file_path)[1]   
    gpt3_response = read_json(file_path)
    return {'id': id, 'gpt_response': gpt3_response['choices'][0]['text']}

def read_and_parse_perspective(file_path):
    toxicity_value = np.nan
    id = re.findall(r'\d+',file_path)[0]
    try:
        perspective_response = read_json(file_path)
        attribute_scores = perspective_response.get('attributeScores')
        if (attribute_scores):
            toxicity_value = attribute_scores.get(
                'TOXICITY',{}).get('summaryScore',{}).get('value')
        return {
            'id': id, 'perspective_response': toxicity_value,
            'error': perspective_response.get('error')
            }
    except Exception as e:
        print(f'Error in id {id}: {str(e)}')

def parse_boolean_text(t):
    # NOTE: We assume here that we get an answer from a well behaved set
    # We signify another response (should be rare) with -1,
    # and inspect these by hand
    t = t.replace('\n', '')
    t = t.lower().split(' ')
    for val in ['true', 'false', 'yes', 'no', 'true.', 'false.', 'yes.', 'no.']:
        if val in t:
            return int(val == 'true') or int(val == 'yes')

    # Special case: sometimes GPT3 returns a negation.
    # I.e. "This phrase is not toxic" -> false
    # this might be a bit of a hacky fix...
    if 'not' in t:
        return 0
    return -1

# %%
gpt3_responses = [read_and_parse_gpt3(file_path) for file_path in file_paths_gpt3]
perspective_responses = [read_and_parse_perspective(file_path) for file_path in file_paths_perspective]

# %%
gpt3_responses = pd.DataFrame(gpt3_responses)
perspective_responses = pd.DataFrame(perspective_responses)

# %%
gpt_vs_perspective = gpt3_responses.merge(
    perspective_responses,
    on='id',
    how='outer'
)

# %%
gpt_vs_perspective = gpt_vs_perspective.rename(columns = {'error': 'perspective_error'})

# %%
gpt_vs_perspective = gpt_vs_perspective.assign(
    gpt_response_txt = gpt_vs_perspective.gpt_response,
    gpt_response = gpt_vs_perspective.gpt_response.map(lambda x: parse_boolean_text(x)),
    id = test_df_sampled.id.astype(int)
    )

# %%
test_df_sampled = test_df_sampled.merge(
    gpt_vs_perspective,
    on='id',
    how='outer'
    )

# %%
test_df_sampled = test_df_sampled.assign(
    perspective_response_bin = (
        test_df_sampled.perspective_response > 0.5).astype(int)
)

# %%
test_df_sampled.to_csv(
    '../data/processed/tweeteval_comparisson_gpt3_perspective.csv'
)

# %%
test_df_sampled = pd.read_csv(
    '../data/processed/tweeteval_comparisson_gpt3_perspective.csv'
)

# %%
test_df_sampled = test_df_sampled.loc[
    (test_df_sampled.gpt_response.isin([0,1])) & 
    (test_df_sampled.perspective_error.isnull())
    ]
len(test_df_sampled)
# Out:
# 990

# %%
np.sum(
    test_df_sampled.perspective_response_bin == test_df_sampled.label
    )/len(test_df_sampled.perspective_response_bin)
# Out:
# 0.45151515151515154

# %%
np.sum(
    test_df_sampled.gpt_response == test_df_sampled.label
    )/len(test_df_sampled.gpt_response)
# Out:
# 0.46565656565656566

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
f1_score_ = f1_score(
    test_df_sampled.label,
    test_df_sampled.perspective_response_bin
)
print(f'F1: {np.round(f1_score_,3)}')
precision = precision_score(
    test_df_sampled.label,
    test_df_sampled.perspective_response_bin
)
print(f'Precision: {np.round(precision,3)}')
recall = recall_score(
    test_df_sampled.label,
    test_df_sampled.perspective_response_bin
)
print(f'Recall: {np.round(recall,3)}')
# Out:
# F1: 0.485
# Precision: 0.397
# Recall: 0.624

# %%
f1_score_ = f1_score(
    test_df_sampled.label,
    test_df_sampled.gpt_response
)
print(f'F1: {np.round(f1_score_,3)}')
precision = precision_score(
    test_df_sampled.label,
    test_df_sampled.gpt_response
)
print(f'Precision: {np.round(precision,3)}')
recall = recall_score(
    test_df_sampled.label,
    test_df_sampled.gpt_response
)
print(f'Recal: {np.round(recall,3)}')
# Out:
# F1: 0.518
# Precision: 0.413
# Recal: 0.693
